# %%
import requests
import pandas as pd
import json
import duckdb

# %%
r = requests.get("https://data.caf.fr/api/explore/v2.1/catalog/datasets/txcouv_pe_epci/records?refine=annee%3A%222023%22")

# %%
data_pe = r.json()

# %%
data_pe.keys()
# Out:
# dict_keys(['total_count', 'results'])

# %%
data_pe['results'][0].keys()
# Out:
# dict_keys(['annee', 'numepci', 'nomepci', 'txcouv_psu_col_epci', 'txcouv_hors_psu_col_epci', 'txcouv_eaje_epci', 'txcouv_prescol_epci', 'txcouv_am_ind_epci', 'txcouv_gad_ind_epci', 'txcouv_ind_epci', 'txcouv_epci'])

# %%
df_pe = pd.json_normalize(data_pe['results'])

# %%
df_pe.shape
# Out:
# (10, 11)

# %%
query = """ 
SELECT 
    numepci as siren,
    txcouv_epci
FROM df_pe
WHERE txcouv_epci IS NOT NULL
ORDER BY numepci
"""

df_pe_final = duckdb.sql(query)

# %%
df_pe_final
# Out:
# ┌───────────┬─────────────┐
# │   siren   │ txcouv_epci │
# │  varchar  │   double    │
# ├───────────┼─────────────┤
# │ 200000438 │        76.3 │
# │ 200035723 │        56.2 │
# │ 200043065 │        65.8 │
# │ 200066223 │        44.0 │
# │ 200067122 │        45.3 │
# │ 200069912 │        58.6 │
# │ 200070977 │        51.0 │
# │ 200090579 │        71.0 │
# │ 240700864 │        65.0 │
# │ 248500258 │        86.2 │
# ├───────────┴─────────────┤
# │ 10 rows       2 columns │
# └─────────────────────────┘

# %%
df_epci = pd.read_csv("../data/data_pe/raw/data_epci.csv",encoding= 'latin1',sep=';')
df_epci
# Out:
#       dept        siren                      raison_sociale nature_juridique  \
# 0       01  200029999.0  CC Rives de l'Ain - Pays du Cerdon               CC
# 1       01  200029999.0  CC Rives de l'Ain - Pays du Cerdon               CC
# 2       01  200029999.0  CC Rives de l'Ain - Pays du Cerdon               CC
# 3       01  200029999.0  CC Rives de l'Ain - Pays du Cerdon               CC
# 4       01  200029999.0  CC Rives de l'Ain - Pays du Cerdon               CC
# ...    ...          ...                                 ...              ...
# 34867   2B  242020105.0                 CC de Calvi Balagne               CC
# 34868   2B  242020105.0                 CC de Calvi Balagne               CC
# 34869   2B  242020105.0                 CC de Calvi Balagne               CC
# 34870   2B  242020105.0                 CC de Calvi Balagne               CC
# 34871  NaN          NaN                                 NaN              NaN
#
#       mode_financ  nb_membres total_pop_tot total_pop_mun dep_com  insee  \
# 0             FPU        14.0        15 156        14 873      01  01304
# 1             FPU        14.0        15 156        14 873      01  01199
# 2             FPU        14.0        15 156        14 873      01  01363
# 3             FPU        14.0        15 156        14 873      01  01314
# 4             FPU        14.0        15 156        14 873      01  01273
# ...           ...         ...           ...           ...     ...    ...
# 34867         FPU        14.0        12 842        12 638      2B  2B138
# 34868         FPU        14.0        12 842        12 638      2B  2B296
# 34869         FPU        14.0        12 842        12 638      2B  2B153
# 34870         FPU        14.0        12 842        12 638      2B  2B025
# 34871         NaN         NaN           NaN           NaN     NaN    NaN
#
#        siren_membre           nom_membre ptot_2025 pmun_2025
# 0       210103040.0           Pont-d'Ain     2 912     2 862
# 1       210101994.0            Jujurieux     2 246     2 209
# 2       210103636.0  Saint-Jean-le-Vieux     1 873     1 799
# 3       210103149.0                Priay     1 826     1 803
# 4       210102737.0     Neuville-sur-Ain     1 823     1 798
# ...             ...                  ...       ...       ...
# 34867   212001382.0           Lavatoggio       158       156
# 34868   212002968.0        Sant'Antonino       133       132
# 34869   212001531.0                Manso       120       117
# 34870   212000251.0             Avapessa        81        81
# 34871           NaN                  NaN       NaN       NaN
#
# [34872 rows x 14 columns]

# %%
query_epci = """ 
SELECT DISTINCT siren as id_epci,
raison_sociale as nom_epci,
dept
FROM df_epci
"""

df_epci_final = duckdb.sql(query_epci)
df_epci_final
# Out:
# ┌─────────────┬─────────────────────────────────────────────────┬─────────┐
# │   id_epci   │                    nom_epci                     │  dept   │
# │   double    │                     varchar                     │ varchar │
# ├─────────────┼─────────────────────────────────────────────────┼─────────┤
# │ 200040350.0 │ CC Bugey Sud                                    │ 01      │
# │ 200042497.0 │ CC Dombes Saône Vallée                          │ 01      │
# │ 200071371.0 │ CC Bresse et Saône                              │ 01      │
# │ 200071751.0 │ CA du Bassin de Bourg-en-Bresse                 │ 01      │
# │ 240100610.0 │ CC de la Côtière à Montluel                     │ 01      │
# │ 200043495.0 │ CA du Pays de Laon                              │ 02      │
# │ 200071769.0 │ CC Picardie des Châteaux                        │ 02      │
# │ 200071983.0 │ CC Thiérache Sambre et Oise                     │ 02      │
# │ 240200444.0 │ CC de la Thiérache du Centre                    │ 02      │
# │ 240200493.0 │ CC du Pays du Vermandois                        │ 02      │
# │      ·      │            ·                                    │ ·       │
# │      ·      │            ·                                    │ ·       │
# │      ·      │            ·                                    │ ·       │
# │ 249500430.0 │ CC Sausseron Impressionnistes                   │ 95      │
# │ 249500513.0 │ CC du Vexin-Val de Seine                        │ 95      │
# │ 249710070.0 │ CA Grand Sud Caraïbe                            │ 971     │
# │ 200027548.0 │ CC des Savanes                                  │ 973     │
# │ 249730052.0 │ CC de l'Est Guyanais                            │ 973     │
# │ 249740085.0 │ CA du Sud                                       │ 974     │
# │ 249740093.0 │ CA Intercommunale de la Réunion Est (CIREST)    │ 974     │
# │ 249740119.0 │ CA Intercommunale du Nord de la Réunion (CINOR) │ 974     │
# │ 200060457.0 │ CA de Dembeni / Mamoudzou                       │ 976     │
# │ 200073252.0 │ CC de la Castagniccia-Casinca                   │ 2B      │
# ├─────────────┴─────────────────────────────────────────────────┴─────────┤
# │ 1256 rows (20 shown)                                          3 columns │
# └─────────────────────────────────────────────────────────────────────────┘

# %%
query = """
        SELECT 
            s1.dept,
            s1.id_epci,
            s1.nom_epci,
            'i130' AS id_indicator,
            s2.txcouv_epci as valeur_brute   
        FROM df_epci_final as s1
        LEFT JOIN df_pe_final as s2
        ON s1.id_epci = s2.siren
        ORDER BY s1.dept, s1.id_epci
        """
    
df_complete = duckdb.sql(query)
df_complete
# Out:
# ┌─────────┬─────────────┬─────────────────────────────────────────────────┬──────────────┬──────────────┐
# │  dept   │   id_epci   │                    nom_epci                     │ id_indicator │ valeur_brute │
# │ varchar │   double    │                     varchar                     │   varchar    │    double    │
# ├─────────┼─────────────┼─────────────────────────────────────────────────┼──────────────┼──────────────┤
# │ 01      │ 200029999.0 │ CC Rives de l'Ain - Pays du Cerdon              │ i130         │         NULL │
# │ 01      │ 200040350.0 │ CC Bugey Sud                                    │ i130         │         NULL │
# │ 01      │ 200042497.0 │ CC Dombes Saône Vallée                          │ i130         │         NULL │
# │ 01      │ 200042935.0 │ CA Haut-Bugey Agglomération                     │ i130         │         NULL │
# │ 01      │ 200069193.0 │ CC de la Dombes                                 │ i130         │         NULL │
# │ 01      │ 200070118.0 │ CC Val de Saône Centre                          │ i130         │         NULL │
# │ 01      │ 200070555.0 │ CC de la Veyle                                  │ i130         │         NULL │
# │ 01      │ 200071371.0 │ CC Bresse et Saône                              │ i130         │         NULL │
# │ 01      │ 200071751.0 │ CA du Bassin de Bourg-en-Bresse                 │ i130         │         NULL │
# │ 01      │ 240100610.0 │ CC de la Côtière à Montluel                     │ i130         │         NULL │
# │ ·       │      ·      │     ·                                           │  ·           │           ·  │
# │ ·       │      ·      │     ·                                           │  ·           │           ·  │
# │ ·       │      ·      │     ·                                           │  ·           │           ·  │
# │ 974     │ 249740085.0 │ CA du Sud                                       │ i130         │         NULL │
# │ 974     │ 249740093.0 │ CA Intercommunale de la Réunion Est (CIREST)    │ i130         │         NULL │
# │ 974     │ 249740101.0 │ CA Territoire de la Côte Ouest (TCO)            │ i130         │         NULL │
# │ 974     │ 249740119.0 │ CA Intercommunale du Nord de la Réunion (CINOR) │ i130         │         NULL │
# │ 976     │ 200050532.0 │ CC de Petite-Terre                              │ i130         │         NULL │
# │ 976     │ 200059871.0 │ CC du Centre-Ouest                              │ i130         │         NULL │
# │ 976     │ 200060457.0 │ CA de Dembeni / Mamoudzou                       │ i130         │         NULL │
# │ 976     │ 200060465.0 │ CA du Grand Nord de Mayotte                     │ i130         │         NULL │
# │ 976     │ 200060473.0 │ CC du Sud                                       │ i130         │         NULL │
# │ NULL    │        NULL │ NULL                                            │ i130         │         NULL │
# ├─────────┴─────────────┴─────────────────────────────────────────────────┴──────────────┴──────────────┤
# │ 1256 rows (20 shown)                                                                        5 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────┘
