# %%
from bs4 import BeautifulSoup
import pandas as pd
import csv
import re

file_path = "/home/guillaume/Documents/Github/diag360/data/data_media/raw/medias_locaux.txt"

def extraire_donnees_media(chemin_fichier):
        with open(chemin_fichier, 'r', encoding='utf-8') as f:
            contenu = f.read()

        # 1. On récupère d'abord tout le texte entre les balises <a>...</a>
        # Le format est : <a href="#">Texte (Ville)</a>
        balises = re.findall(r'<a href="#">(.*?)</a>', contenu)

        data = []

        for item in balises:
            # 2. On sépare le nom de la ville
            # On cherche la DERNIÈRE parenthèse de la chaîne
            # (.*) -> Nom du média
            # \s -> espace
            # \(([^)]+)\)$ -> Contenu de la dernière parenthèse à la fin de la chaîne
            match = re.search(r'(.*)\s\(([^)]+)\)$', item)

            if match:
                nom_media = match.group(1).strip()
                ville = match.group(2).strip()
                data.append([nom_media, ville])
            else:
                # Cas de secours si le format est différent
                data.append([item, "Inconnue"])

        # 3. Création du DataFrame
        df = pd.DataFrame(data, columns=['Nom_media', 'Ville'])
        return df

    # Exécution
try:
    df_medias = extraire_donnees_media(str(file_path))
    print("Extraction réussie :")
    print(df_medias.head())

    # Optionnel : Sauvegarder en CSV
    df_medias.to_csv("medias_extraits.csv", index=False)
except Exception as e:
    print(f"Erreur lors de la lecture du fichier : {e}")

df_medias.head()
# Out:
# Extraction réussie :
#         Nom_media                   Ville
# 0   Zones D'Ondes                    Caen
# 1          Tsf 98  Hérouville-Saint-Clair
# 2  Tendance Ouest                    Caen
# 3    Sport à Caen                    Caen
# 4       Radio VFM                    Caen
#         Nom_media                   Ville
# 0   Zones D'Ondes                    Caen
# 1          Tsf 98  Hérouville-Saint-Clair
# 2  Tendance Ouest                    Caen
# 3    Sport à Caen                    Caen
# 4       Radio VFM                    Caen

# %%
df_medias.head(70)
# Out:
#          Nom_media                   Ville
# 0    Zones D'Ondes                    Caen
# 1           Tsf 98  Hérouville-Saint-Clair
# 2   Tendance Ouest                    Caen
# 3     Sport à Caen                    Caen
# 4        Radio VFM                    Caen
# ..             ...                     ...
# 65    Ouest-France                 Loudéac
# 66    Ouest-France                Guingamp
# 67    Ouest-France            Saint-Brieuc
# 68    Ouest-France          Lamballe-Armor
# 69    Ouest-France                 Lannion
#
# [70 rows x 2 columns]

# %%
df_medias.to_csv("../data/processed/media.csv", index=False, sep=";")

# %%
import os
import sys
from pathlib import Path
import requests

def download_file(url: str, extract_to: str = '.', filename: str = None) -> None : 
    """
    Télécharge un fichier depuis une URL et l'enregistre localement.

    Le fichier est téléchargé uniquement s'il n'existe pas déjà
    dans le répertoire de destination.

    Parameters
    ----------
    url : str
        URL du fichier à télécharger.
    extract_to : str, optional
        Répertoire de destination du fichier (par défaut : répertoire courant).
    filename : str
        Nom du fichier local (avec extension).

    Raises
    ------
    requests.exceptions.RequestException
        En cas d'erreur réseau lors du téléchargement.
    """

    if not os.path.exists(extract_to):
        os.makedirs(extract_to, exist_ok=True)
        print(f"Dossier créé : {extract_to}")

    filename = os.path.join(extract_to, filename)

    if not os.path.exists(filename):
        response = requests.get(url)
        response.raise_for_status()
        print(f"Téléchargement du fichier : {filename}")

        with open(filename, 'wb') as f:
            f.write(response.content)
        print(f"Fichier téléchargé avec succès : {filename}")

def float_to_codepostal(df: pd.DataFrame, col: str) -> pd.DataFrame:
    """
    Convertit une colonne contenant des codes postaux numériques en format chaîne à 5 caractères.

    Cette fonction est destinée aux cas où les codes postaux ont été lus comme
    des nombres flottants (ex. `1400.0`) et doivent être restaurés en chaînes
    avec zéros initiaux (ex. `01400`).

    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame contenant la colonne à transformer.
    col : str
        Nom de la colonne contenant les codes postaux.

    Returns
    -------
    pandas.DataFrame
        DataFrame avec la colonne des codes postaux convertie en chaînes
        de longueur 5.

    Notes
    -----
    - La fonction modifie le DataFrame en place et le retourne.
    - Les valeurs manquantes sont converties en chaînes `'nan'`
      si elles ne sont pas nettoyées en amont.
    """

    df[col] = (
        df[col]
        .astype(str)
        .str.replace(".0", "", regex=False)
        .str.zfill(5)
    )
    return df

def create_dataframe_communes(dir_path):
    com_url = (
        "https://www.data.gouv.fr/api/1/datasets/r/f5df602b-3800-44d7-b2df-fa40a0350325"
    )
    download_file(com_url, extract_to=dir_path, filename="communes_france_2025.csv")
    df_com = pd.read_csv(dir_path / "communes_france_2025.csv")
    df_com = float_to_codepostal(df_com, "code_postal")
    return df_com

df_com = create_dataframe_communes(Path("../data/raw/"))
# Out:
# /tmp/ipykernel_24023/1996302946.py:84: DtypeWarning: Columns (1,12,14,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_com = pd.read_csv(dir_path / "communes_france_2025.csv")

# %%
df_com.head()
# Out:
#    Unnamed: 0 code_insee             nom_standard        nom_sans_pronom  \
# 0           0      01001  L'Abergement-Clémenciat  Abergement-Clémenciat
# 1           1      01002    L'Abergement-de-Varey    Abergement-de-Varey
# 2           2      01004        Ambérieu-en-Bugey      Ambérieu-en-Bugey
# 3           3      01005      Ambérieux-en-Dombes    Ambérieux-en-Dombes
# 4           4      01006                  Ambléon                Ambléon
#
#                      nom_a                      nom_de  \
# 0  à Abergement-Clémenciat  de l'Abergement-Clémenciat
# 1    à Abergement-de-Varey    de l'Abergement-de-Varey
# 2      à Ambérieu-en-Bugey         d'Ambérieu-en-Bugey
# 3    à Ambérieux-en-Dombes       d'Ambérieux-en-Dombes
# 4                à Ambléon                   d'Ambléon
#
#            nom_sans_accent   nom_standard_majuscule typecom typecom_texte  \
# 0  l-abergement-clemenciat  L'ABERGEMENT-CLÉMENCIAT     COM       commune
# 1    l-abergement-de-varey    L'ABERGEMENT-DE-VAREY     COM       commune
# 2        amberieu-en-bugey        AMBÉRIEU-EN-BUGEY     COM       commune
# 3      amberieux-en-dombes      AMBÉRIEUX-EN-DOMBES     COM       commune
# 4                  ambleon                  AMBLÉON     COM       commune
#
#    ...  longitude_mairie latitude_centre longitude_centre grille_densite  \
# 0  ...             4.921          46.153            4.926              6
# 1  ...             5.423          46.009            5.428              6
# 2  ...             5.360          45.961            5.373              2
# 3  ...             4.903          45.996            4.912              5
# 4  ...             5.601          45.750            5.594              6
#
#              grille_densite_texte niveau_equipements_services  \
# 0        Rural à habitat dispersé                         0.0
# 1        Rural à habitat dispersé                         0.0
# 2  Centres urbains intermédiaires                         3.0
# 3                   Bourgs ruraux                         1.0
# 4        Rural à habitat dispersé                         0.0
#
#                    niveau_equipements_services_texte  \
# 0                                  communes non pôle
# 1                                  communes non pôle
# 2  centres structurants d'équipements et de services
# 3        centres locaux d'équipements et de services
# 4                                  communes non pôle
#
#                           gentile  \
# 0                             NaN
# 1  Abergementais, Abergementaises
# 2          Ambarrois, Ambarroises
# 3                       Ambarrois
# 4                      Ambléonais
#
#                                        url_wikipedia  \
# 0  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 1  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 2  https://fr.wikipedia.org/wiki/fr:Ambérieu-en-B...
# 3  https://fr.wikipedia.org/wiki/fr:Ambérieux-en-...
# 4           https://fr.wikipedia.org/wiki/fr:Ambléon
#
#                                      url_villedereve
# 0  https://villedereve.fr/ville/01001-l-abergemen...
# 1  https://villedereve.fr/ville/01002-l-abergemen...
# 2  https://villedereve.fr/ville/01004-amberieu-en...
# 3  https://villedereve.fr/ville/01005-amberieux-e...
# 4         https://villedereve.fr/ville/01006-ambleon
#
# [5 rows x 47 columns]

# %%
df_com.columns
# Out:
# Index(['Unnamed: 0', 'code_insee', 'nom_standard', 'nom_sans_pronom', 'nom_a',
#        'nom_de', 'nom_sans_accent', 'nom_standard_majuscule', 'typecom',
#        'typecom_texte', 'reg_code', 'reg_nom', 'dep_code', 'dep_nom',
#        'canton_code', 'canton_nom', 'epci_code', 'epci_nom', 'academie_code',
#        'academie_nom', 'code_postal', 'codes_postaux', 'zone_emploi',
#        'code_insee_centre_zone_emploi', 'code_unite_urbaine',
#        'nom_unite_urbaine', 'taille_unite_urbaine',
#        'type_commune_unite_urbaine', 'statut_commune_unite_urbaine',
#        'population', 'superficie_hectare', 'superficie_km2', 'densite',
#        'altitude_moyenne', 'altitude_minimale', 'altitude_maximale',
#        'latitude_mairie', 'longitude_mairie', 'latitude_centre',
#        'longitude_centre', 'grille_densite', 'grille_densite_texte',
#        'niveau_equipements_services', 'niveau_equipements_services_texte',
#        'gentile', 'url_wikipedia', 'url_villedereve'],
#       dtype='object')

# %%
import duckdb

# %%
query = """
SELECT 
    code_insee,
    nom_standard,
    dep_code,
    epci_code,
    epci_nom,
    df_medias.Nom_media AS nom_media  
FROM df_com  
INNER JOIN df_medias
ON df_com.nom_standard = df_medias.Ville
"""

df_result = duckdb.query(query).to_df()
df_result.shape
# Out:
# (2708, 6)

# %%
df_result[df_result["d"] == "14"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_result[df_result["d"] == "14"]
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'd'

# %% [markdown]
# ## Suppression des doublons de villes

# %%
dup_com = (
    df_com
    .groupby("nom_standard")
    .size()
    .reset_index(name="n_com")
    .query("n_com > 1")
)

dup_com
# Out:
#       nom_standard  n_com
# 2        Abancourt      2
# 34       Aboncourt      2
# 45           Abzac      2
# 63         Achères      2
# 143         Aiglun      2
# ...            ...    ...
# 32581      Étaules      2
# 32590    Éterpigny      2
# 32636      Étréchy      3
# 32641    Étrépilly      2
# 32687       Œuilly      2
#
# [1450 rows x 2 columns]

# %%
dup_medias = (
    df_medias
    .groupby("Ville")
    .size()
    .reset_index(name="n_medias")
    .query("n_medias > 1")
)
dup_medias
# Out:
#                   Ville  n_medias
# 2                  Agen         7
# 6       Aire-sur-la-Lys         2
# 8       Aix-en-Provence         5
# 10              Ajaccio         6
# 11          Albertville         4
# ..                  ...       ...
# 949             Ébreuil         2
# 950             Épernay         3
# 951              Épinal         7
# 954              Évreux         6
# 955  Évry-Courcouronnes         4
#
# [400 rows x 2 columns]

# %%
villes_ambigues = (
    dup_com
    .merge(dup_medias, left_on="nom_standard", right_on="Ville", how="inner")
)

villes_ambigues
# Out:
#      nom_standard  n_com          Ville  n_medias
# 0        Bailleul      3       Bailleul         2
# 1     Blanquefort      2    Blanquefort         3
# 2         Castres      2        Castres         2
# 3        Chaumont      5       Chaumont         6
# 4         Clamecy      2        Clamecy         3
# 5         Falaise      2        Falaise         2
# 6           Flers      3          Flers         2
# 7        Fontaine      3       Fontaine         2
# 8     La Rochelle      2    La Rochelle         8
# 9          Langon      2         Langon         3
# 10       Marmagne      3       Marmagne         2
# 11      Montreuil      3      Montreuil         6
# 12        Moulins      3        Moulins         8
# 13         Olivet      2         Olivet         2
# 14         Prades      5         Prades         2
# 15      Rochefort      2      Rochefort         2
# 16         Ruffec      2         Ruffec         2
# 17   Saint-Claude      2   Saint-Claude         2
# 18    Saint-Denis      4    Saint-Denis         2
# 19  Saint-Nazaire      3  Saint-Nazaire        10
# 20     Saint-Omer      2     Saint-Omer         2
# 21  Saint-Raphaël      2  Saint-Raphaël         2
# 22          Ussel      3          Ussel         2
# 23        Valence      3        Valence        11
# 24         Verdun      2         Verdun         6
# 25         Vernon      3         Vernon         2

# %%
RULES_CONFIG = {
        "Bailleul": "59",
        "Castres": "81",
        "Chaumont": "52",
        "Clamecy": "58",
        "Falaise": "14",
        "Flers": "61",
        "Fontaine": "38",
        "La Rochelle": "17",
        "Langon": "33",
        "Marmagne": "71",
        "Montreuil": "93",
        "Moulins": "03",
        "Olivet": "45",
        "Prades": "66",
        "Rochefort": "17",
        "Saint-Claude": "39",
        "Saint-Nazaire": "44",
        "Saint-Omer": "62",
        "Saint-Raphaël": "83",
        "Ussel": "19",
        "Verdun": "55",
        "Vernon": "27",

        # Cas complexes avec conditions multiples
        "Blanquefort": lambda r: r["dep_code"] == '33' and r["nom_media"] == "R.I.G",

        "Valence": lambda r: (
            (r["dep_code"] == '82' and r["nom_media"] in ["VFM", "La Dépêche du Midi"]) or
            (r["dep_code"] == '26' and r["nom_media"] not in ["VFM", "La Dépêche du Midi"])
        )
    }

def filter_logic(row):
    ville = row["nom_standard"]

        # Si la ville n'est pas dans le dictionnaire, on garde la ligne par défaut
    if ville not in RULES_CONFIG:
        return True

    regle = RULES_CONFIG[ville]

        # Si la règle est une fonction (cas complexes)
    if callable(regle):
        return regle(row)

        # Sinon, c'est une règle simple de département (comparaison directe)
    return row["dep_code"] == regle

    # Application du filtre en une seule ligne
df_temp = df_result[df_result.apply(filter_logic, axis=1)].copy()

df_temp.drop_duplicates(inplace=True)
print(f"Après filtrage, df_temp.shape: {df_temp.shape}")
# Out:
# Après filtrage, df_temp.shape: (2506, 6)

# %%
#différence des villes entre df_médias et df_result_final
set_villes_medias = set(df_medias["Ville"].unique())
set_villes_result = set(df_temp["nom_standard"].unique())
set_villes_diff = set_villes_medias - set_villes_result
set_villes_diff
# Out:
# {'Bourg Les Valence',
#  'Charleville-Mézieres',
#  'Cherbourg',
#  'Cherbourg-En-Cotentin',
#  'Château du Loir',
#  'Cierp Gaud',
#  'Digne les Bains',
#  'Echouboulains',
#  'Inconnue',
#  'SAINT-AIGNAN DE GRAND LIEU',
#  'Saint-Quentin-en-Yvelines',
#  'Sanary',
#  'St Philbert de Grand-Lieu',
#  'Vaux-Sur-Mer',
#  'la Seyne'}

# %%
ville_mapping = {
    "Bourg Les Valence": "Bourg-lès-Valence",
    "Charleville-Mézieres": "Charleville-Mézières",
    "Cherbourg": "Cherbourg-en-Cotentin",
    "Cherbourg-En-Cotentin": "Cherbourg-en-Cotentin",
    "Château du Loir": "Montval-sur-Loir",
    "Cierp Gaud": "Cierp-Gaud",
    "Digne les Bains": "Digne-les-Bains",
    "Echouboulains": "Échouboulains",
    'Inconnue': "Château-Chinon (Ville)",
    "SAINT-AIGNAN DE GRAND LIEU": "Saint-Aignan-Grandlieu",
    "Saint-Quentin-en-Yvelines": "Montigny-le-Bretonneux",
    "Sanary": "Sanary-sur-Mer",
    "St Philbert de Grand-Lieu": "Saint-Philbert-de-Grand-Lieu",
    "Vaux-Sur-Mer": "Vaux-sur-Mer",
    "la Seyne": "La Seyne-sur-Mer",
}

df_medias["Ville"] = df_medias["Ville"].replace(ville_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 71
#       1 ville_mapping = {
#       2     "7 à Poitiers": "Poitiers",
#       3     "89 Rnb": "Auxerre",
#    (...)
#      68     "S": "Lyon",
#      69 }
# ---> 71 df_medias["Ville"] = df_medias["Ville"].replace(ville_mapping)
#
# NameError: name 'df_medias' is not defined

# %%
nom_mapping = {
    'Mistral Social Club': 'Salon-de-Provence',
    'Mon Pays': 'Toulouse',
    'Tamtam': 'Bezons',
}

df_medias["Ville"] = df_medias["Nom"].replace(nom_mapping)

# %%
df_medias.loc[df_medias["Ville"] ==  "Inconnue"
               , "Nom_media"]
# Out:
# 1588    Frequence Morvan Force 5 (Château-Chinon (Ville))
# Name: Nom_media, dtype: object

# %%
df_com.loc[df_com["nom_standard"] == "Château-Chinon (Ville)"]
# Out:
#        Unnamed: 0 code_insee            nom_standard         nom_sans_pronom  \
# 21533       21533      58062  Château-Chinon (Ville)  Château-Chinon (Ville)
#
#                           nom_a                     nom_de  \
# 21533  à Château-Chinon (Ville)  de Château-Chinon (Ville)
#
#               nom_sans_accent  nom_standard_majuscule typecom typecom_texte  \
# 21533  chateau-chinon-(ville)  CHÂTEAU-CHINON (VILLE)     COM       commune
#
#        ...  longitude_mairie latitude_centre longitude_centre grille_densite  \
# 21533  ...             3.932          47.063            3.927              5
#
#       grille_densite_texte niveau_equipements_services  \
# 21533        Bourgs ruraux                         2.0
#
#                        niveau_equipements_services_texte            gentile  \
# 21533  centres intermédiaires d'équipements et de ser...  Château-Chinonais
#
#                                            url_wikipedia  \
# 21533  https://fr.wikipedia.org/wiki/fr:Château-Chino...
#
#                                          url_villedereve
# 21533  https://villedereve.fr/ville/58062-chateau-chi...
#
# [1 rows x 47 columns]

# %%
df_medias[df_medias["Ville"].isin(set_villes_diff)].shape
# Out:
# (87, 2)

# %%
# Finaliser le DataFrame
df_result_final = df_temp.copy()

# %%
#ligne à supprimer
import requests
url_media_non_independants = "https://raw.githubusercontent.com/mdiplo/Medias_francais/refs/heads/master/medias.tsv"
df = pd.read_csv(url_media_non_independants, sep = "\t")
df
# Out:
#                        Nom                                         Type  \
# 0                     6ter                                   Télévision
# 1               20 Minutes                                         Site
# 2                 ARC Info  Presse (généraliste  politique  économique)
# 3                     Arte                                   Télévision
# 4    Aujourd’hui en France  Presse (généraliste  politique  économique)
# ..                     ...                                          ...
# 213         Vaucluse Matin  Presse (généraliste  politique  économique)
# 214                  Voici  Presse (généraliste  politique  économique)
# 215           Vosges Matin  Presse (généraliste  politique  économique)
# 216                    VSD  Presse (généraliste  politique  économique)
# 217                     W9                                   Télévision
#
#       Periodicite   Echelle     Prix Disparu
# 0             NaN       NaN  Gratuit     NaN
# 1             NaN       NaN  Gratuit     NaN
# 2             NaN    Suisse      NaN     NaN
# 3             NaN    Europe  Gratuit     NaN
# 4       Quotidien  National   Payant     NaN
# ..            ...       ...      ...     ...
# 213     Quotidien  Régional   Payant     NaN
# 214  Hebdomadaire  National   Payant     NaN
# 215     Quotidien  Régional   Payant     NaN
# 216       Mensuel  National   Payant     NaN
# 217           NaN       NaN  Gratuit     NaN
#
# [218 rows x 6 columns]

# %%
#on retire de df_result_final les médias présents dans df
df_final = df_result_final[~df_result_final["media_nom"].isin(df["Nom"])]
df_final.shape
# Out:
# (2223, 6)

# %%
df_final.head(50)
# Out:
#    code_insee             nom_standard dep_code  epci_code  \
# 0       01004        Ambérieu-en-Bugey       01  240100883
# 2       01033               Valserhône       01  240100891
# 3       01053          Bourg-en-Bresse       01  200071751
# 4       01159                 Feillens       01  200071371
# 5       01160          Ferney-Voltaire       01  240100750
# 6       01262                 Montluel       01  240100610
# 8       01328                   Romans       01  200069193
# 9       01344    Saint-Denis-lès-Bourg       01  200071751
# 11      02168          Château-Thierry       02  200072031
# 13      02361                    Guise       02  200071983
# 14      02381                   Hirson       02  240200600
# 15      02408                     Laon       02  200043495
# 17      02627     Proviseux-et-Plesnoy       02  240200576
# 18      02691            Saint-Quentin       02  200071892
# 19      02722                 Soissons       02  240200477
# 20      02738                 Tergnier       02  200071785
# 21      02789                  Vervins       02  240200444
# 22      03036    Bourbon-l'Archambault       03  200071496
# 23      03100                     Diou       03  200071470
# 24      03106        Durdat-Larequille       03  200071512
# 25      03107                  Ébreuil       03  200071389
# 26      03190                  Moulins       03  200071140
# 27      03217              Saint-Angel       03  200071512
# 29      04006                    Allos       04  200068625
# 30      04039               Castellane       04  200068625
# 31      04070          Digne-les-Bains       04  200067437
# 32      04092                 La Garde       04  200068625
# 33      04104                   Limans       04  240400440
# 34      04112                 Manosque       04  200034700
# 35      04160                Reillanne       04  200071025
# 36      04209                 Sisteron       04  200068765
# 37      05040                  Chorges       05  200067742
# 39      06004                  Antibes       06  240600585
# 40      06023           Breil-sur-Roya       06  240600551
# 41      06027           Cagnes-sur-Mer       06  200030195
# 42      06029                   Cannes       06  200039915
# 43      06030                Le Cannet       06  200039915
# 44      06033                   Carros       06  200030195
# 45      06068                  Gourdon       06  240600585
# 46      06069                   Grasse       06  200039857
# 48      06088                     Nice       06  200030195
# 49      06094                    Péone       06  200039931
# 50      06099           Puget-Théniers       06  200039931
# 51      06123     Saint-Laurent-du-Var       06  200030195
# 52      06149               La Trinité       06  200030195
# 53      06152                 Valbonne       06  240600585
# 54      06155                Vallauris       06  240600585
# 55      07010                  Annonay       07  200072015
# 57      03161  Marcillat-en-Combraille       03  200071082
# 58      05006   L'Argentière-la-Bessée       05  240500462
#
#                                          epci_nom  \
# 0                        CC de la Plaine de l'Ain
# 2                  CC du Pays Bellegardien (CCPB)
# 3                 CA du Bassin de Bourg-en-Bresse
# 4                              CC Bresse et Saône
# 5                               CA du Pays de Gex
# 6                     CC de la Côtière à Montluel
# 8                                 CC de la Dombes
# 9                 CA du Bassin de Bourg-en-Bresse
# 11             CA de la Région de Château-Thierry
# 13                    CC Thiérache Sambre et Oise
# 14                          CC des Trois Rivières
# 15                             CA du Pays de Laon
# 17                     CC de la Champagne Picarde
# 18                         CA du Saint-Quentinois
# 19                 CA GrandSoissons Agglomération
# 20                     CA Chauny-Tergnier-La Fère
# 21                   CC de la Thiérache du Centre
# 22                       CC du Bocage Bourbonnais
# 23                 CC Entr'Allier Besbre et Loire
# 24      CC Commentry Montmarault Néris Communauté
# 25               CC Saint-Pourçain Sioule Limagne
# 26                          CA Moulins Communauté
# 27      CC Commentry Montmarault Néris Communauté
# 29  CC Alpes-Provence-Verdon - Sources de Lumière
# 30  CC Alpes-Provence-Verdon - Sources de Lumière
# 31                CA Provence-Alpes-Agglomération
# 32  CC Alpes-Provence-Verdon - Sources de Lumière
# 33        CC Pays Forcalquier et Montagne de Lure
# 34        CA Durance-Lubéron-Verdon Agglomération
# 35                CC Haute-Provence-Pays de Banon
# 36                        CC du Sisteronais-Buëch
# 37                                CC Serre-Ponçon
# 39                         CA de Sophia Antipolis
# 40                     CA de la Riviera Française
# 41                     Métropole Nice Côte d'Azur
# 42                       CA Cannes Pays de Lérins
# 43                       CA Cannes Pays de Lérins
# 44                     Métropole Nice Côte d'Azur
# 45                         CA de Sophia Antipolis
# 46                           CA du Pays de Grasse
# 48                     Métropole Nice Côte d'Azur
# 49                                CC Alpes d'Azur
# 50                                CC Alpes d'Azur
# 51                     Métropole Nice Côte d'Azur
# 52                     Métropole Nice Côte d'Azur
# 53                         CA de Sophia Antipolis
# 54                         CA de Sophia Antipolis
# 55                         CA Annonay Rhône Agglo
# 57                        CA Montluçon Communauté
# 58                          CC du Pays des Ecrins
#
#                         media_nom
# 0             Le Journal du Bugey
# 2                  Exil Sorgia FM
# 3   France 3 Rhone Alpes Auvergne
# 4                  L'Aindépendant
# 5                           Zones
# 6                        FC Radio
# 8                         Zig-Zag
# 9                    Eco de l'Ain
# 11              R2M La Radio Plus
# 13               L'Aisne nouvelle
# 14       Le Courrier – La Gazette
# 15       L'Agriculteur de l'Aisne
# 17                           3Des
# 18               L'Aisne nouvelle
# 19            Le Vase Communicant
# 20               L'Aisne nouvelle
# 21                   La Thiérache
# 22               Qui Qu'En Grogne
# 23                       Clash FM
# 24                    Regard Actu
# 25                     Coquelicot
# 26                         Bocage
# 27                 Actus Limousin
# 29      Oxygene Ubaye Val D'Allos
# 30              Fréquence Mistral
# 31          France 3 Mediterranee
# 32             Radio Maria France
# 33                  Radio Zinzine
# 34              Fréquence Mistral
# 35             La Canarde Sauvage
# 36              Fréquence Mistral
# 37                       BFM DICI
# 39                     Nice Matin
# 40                         Vallée
# 41                     Nice Matin
# 42                   Cannes Radio
# 43      Association -6 / Radio As
# 44                    Fréquence K
# 45                  Montceau News
# 46              Agora Côte D'Azur
# 48                      Actu Nice
# 49           Oxygene Hautes-Alpes
# 50                    Grimaldi FM
# 51                      La Strada
# 52           Patriote Côte d'Azur
# 53                  Clin D'Œil FM
# 54                  TaVille TaVie
# 55             Le Dauphiné Libéré
# 57                       Tartasse
# 58                        Imagine

# %%
query_by_dept = """ 
SELECT 
    dep_code as dept,
    count(media_nom) AS n_medias
FROM df_final
GROUP BY dep_code
ORDER BY dep_code
"""

nb_medias_par_dept = duckdb.query(query_by_dept).to_df()
nb_medias_par_dept
# Out:
#    dept  n_medias
# 0    01        19
# 1    02        14
# 2    03        15
# 3    04        12
# 4    05        11
# ..  ...       ...
# 94   94         5
# 95   95        10
# 96  971         1
# 97  972         1
# 98  974         2
#
# [99 rows x 2 columns]

# %%
query_by_epci = """ 
SELECT
    dep_code as dept,
    epci_code,
    count(media_nom) AS n_medias
FROM df_final
GROUP BY dep_code, epci_code
ORDER BY dep_code, epci_code
"""

nb_medias_par_epci = duckdb.query(query_by_epci).to_df()
nb_medias_par_epci
# Out:
#     dept  epci_code  n_medias
# 0     01  200069193         1
# 1     01  200071371         1
# 2     01  200071751        11
# 3     01  240100610         2
# 4     01  240100750         1
# ..   ...        ...       ...
# 597   95  249500513         1
# 598  971  249710047         1
# 599  972  200041788         1
# 600  974  249740077         1
# 601  974  249740119         1
#
# [602 rows x 3 columns]
